# %% [markdown]
# # Camera Simulator Tutorial

# %% [markdown]
# First we need to import the camera_simulator package and numpy

# %%
import camera_simulator
from camera_simulator import lens, sensor
import numpy as np

# %% [markdown]
# We create a random image, the sensor and the lens objects

# %%
np.random.seed(10) # We temporally select a seed to be consistent every time we run the code

image = np.random.randint(10, size=(15,10)) # The image of the camera

lens_height = 10 # Height of the lens
lens_widht = 10 # Widht of the lens
lens1 = lens.Lens(lens_height,lens_widht)
sensor_gain = np.random.randint(10) # sensor gain 
sensor1 = sensor.Sensor(sensor_gain,image,lens1)

# %% [markdown]
# The Lens object needs the height and width dimensions to be created.
# The Sensor object needs the gain of the sensor, the image of the camera, the lens of the camera and the maximum iterator if it is not 10.

# %% [markdown]
# The method process in lens checks if the image dimensions are consitent with the lens dimensions.

# %%
lens1.process(image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-9e4f0d77cb42> in <module>
# ----> 1 lens1.process(image)
#
# ~/Documents/Camera_simulator/camera_simulator/lens.py in process(self, image)
#      90         size = image.shape
#      91         if self.height != size[0] or self.width != size[1]:
# ---> 92             raise ValueError("The size of the image is different to the lens height and width.")
#      93         return image
#      94
#
# ValueError: The size of the image is different to the lens height and width.

# %% [markdown]
# In this case, as it was expected, the lens1 height is differet to the image height. To correct this we may change the image height or the lens height. Let's change the lens height.

# %%
lens1.height = 15

# %% [markdown]
# Now, let's try again the process method to check if they have the same dimensions.

# %%
lens1.process(image)
# Out:
# array([[9, 4, 0, 1, 9, 0, 1, 8, 9, 0],
#        [8, 6, 4, 3, 0, 4, 6, 8, 1, 8],
#        [4, 1, 3, 6, 5, 3, 9, 6, 9, 1],
#        [9, 4, 2, 6, 7, 8, 8, 9, 2, 0],
#        [6, 7, 8, 1, 7, 1, 4, 0, 8, 5],
#        [4, 7, 8, 8, 2, 6, 2, 8, 8, 6],
#        [6, 5, 6, 0, 0, 6, 9, 1, 8, 9],
#        [1, 2, 8, 9, 9, 5, 0, 2, 7, 3],
#        [0, 4, 2, 0, 3, 3, 1, 2, 5, 9],
#        [0, 1, 0, 1, 9, 0, 9, 2, 1, 1],
#        [0, 0, 5, 9, 0, 4, 6, 6, 0, 2],
#        [3, 3, 2, 6, 0, 5, 1, 3, 6, 5],
#        [5, 1, 8, 0, 5, 9, 8, 5, 7, 8],
#        [5, 8, 9, 9, 1, 5, 9, 1, 4, 7],
#        [7, 7, 9, 7, 6, 0, 3, 9, 4, 4]])

# %% [markdown]
# As the dimensions are the same, the process returns us the original image

# %% [markdown]
# Now, we want to know the lenses dimensions, then we can just call them

# %%
print('The lenses height is {} and the width is {}.'.format(lens1.height,lens1.width))
# Out:
# The lenses height is 15 and the width is 10.

# %% [markdown]
# As we select randomly the sensor gain value, we can call it as

# %%
print('The sensor gain is {}.'.format(sensor1.gain))
# Out:
# The sensor gain is 6.

# %% [markdown]
# Also we can change gain value

# %%
sensor1.gain = 3
sensor1.gain
# Out:
# 3

# %% [markdown]
# The process method in the sensor class the image is multiplied by the gain.

# %%
# Updates the dimension values of the lens in the sensor
sensor1.lens_update(lens1)
sensor1.process(image)
# Out:
# array([[27, 12,  0,  3, 27,  0,  3, 24, 27,  0],
#        [24, 18, 12,  9,  0, 12, 18, 24,  3, 24],
#        [12,  3,  9, 18, 15,  9, 27, 18, 27,  3],
#        [27, 12,  6, 18, 21, 24, 24, 27,  6,  0],
#        [18, 21, 24,  3, 21,  3, 12,  0, 24, 15],
#        [12, 21, 24, 24,  6, 18,  6, 24, 24, 18],
#        [18, 15, 18,  0,  0, 18, 27,  3, 24, 27],
#        [ 3,  6, 24, 27, 27, 15,  0,  6, 21,  9],
#        [ 0, 12,  6,  0,  9,  9,  3,  6, 15, 27],
#        [ 0,  3,  0,  3, 27,  0, 27,  6,  3,  3],
#        [ 0,  0, 15, 27,  0, 12, 18, 18,  0,  6],
#        [ 9,  9,  6, 18,  0, 15,  3,  9, 18, 15],
#        [15,  3, 24,  0, 15, 27, 24, 15, 21, 24],
#        [15, 24, 27, 27,  3, 15, 27,  3, 12, 21],
#        [21, 21, 27, 21, 18,  0,  9, 27, 12, 12]])

# %% [markdown]
# The clas Sensor is an iterator, each iteration adds the number of the iteration and the image. Then, we can see the image of each iteration doing a for

# %%
for j in sensor1:
    print("The iteration {}".format(sensor1.i))
    print(j)
# Out:
# The iteration 1
# [[9 4 0 1 9 0 1 8 9 0]
#  [8 6 4 3 0 4 6 8 1 8]
#  [4 1 3 6 5 3 9 6 9 1]
#  [9 4 2 6 7 8 8 9 2 0]
#  [6 7 8 1 7 1 4 0 8 5]
#  [4 7 8 8 2 6 2 8 8 6]
#  [6 5 6 0 0 6 9 1 8 9]
#  [1 2 8 9 9 5 0 2 7 3]
#  [0 4 2 0 3 3 1 2 5 9]
#  [0 1 0 1 9 0 9 2 1 1]
#  [0 0 5 9 0 4 6 6 0 2]
#  [3 3 2 6 0 5 1 3 6 5]
#  [5 1 8 0 5 9 8 5 7 8]
#  [5 8 9 9 1 5 9 1 4 7]
#  [7 7 9 7 6 0 3 9 4 4]]
# The iteration 2
# [[10  5  1  2 10  1  2  9 10  1]
#  [ 9  7  5  4  1  5  7  9  2  9]
#  [ 5  2  4  7  6  4 10  7 10  2]
#  [10  5  3  7  8  9  9 10  3  1]
#  [ 7  8  9  2  8  2  5  1  9  6]
#  [ 5  8  9  9  3  7  3  9  9  7]
#  [ 7  6  7  1  1  7 10  2  9 10]
#  [ 2  3  9 10 10  6  1  3  8  4]
#  [ 1  5  3  1  4  4  2  3  6 10]
#  [ 1  2  1  2 10  1 10  3  2  2]
#  [ 1  1  6 10  1  5  7  7  1  3]
#  [ 4  4  3  7  1  6  2  4  7  6]
#  [ 6  2  9  1  6 10  9  6  8  9]
#  [ 6  9 10 10  2  6 10  2  5  8]
#  [ 8  8 10  8  7  1  4 10  5  5]]
# The iteration 3
# [[11  6  2  3 11  2  3 10 11  2]
#  [10  8  6  5  2  6  8 10  3 10]
#  [ 6  3  5  8  7  5 11  8 11  3]
#  [11  6  4  8  9 10 10 11  4  2]
#  [ 8  9 10  3  9  3  6  2 10  7]
#  [ 6  9 10 10  4  8  4 10 10  8]
#  [ 8  7  8  2  2  8 11  3 10 11]
#  [ 3  4 10 11 11  7  2  4  9  5]
#  [ 2  6  4  2  5  5  3  4  7 11]
#  [ 2  3  2  3 11  2 11  4  3  3]
#  [ 2  2  7 11  2  6  8  8  2  4]
#  [ 5  5  4  8  2  7  3  5  8  7]
#  [ 7  3 10  2  7 11 10  7  9 10]
#  [ 7 10 11 11  3  7 11  3  6  9]
#  [ 9  9 11  9  8  2  5 11  6  6]]
# The iteration 4
# [[12  7  3  4 12  3  4 11 12  3]
#  [11  9  7  6  3  7  9 11  4 11]
#  [ 7  4  6  9  8  6 12  9 12  4]
#  [12  7  5  9 10 11 11 12  5  3]
#  [ 9 10 11  4 10  4  7  3 11  8]
#  [ 7 10 11 11  5  9  5 11 11  9]
#  [ 9  8  9  3  3  9 12  4 11 12]
#  [ 4  5 11 12 12  8  3  5 10  6]
#  [ 3  7  5  3  6  6  4  5  8 12]
#  [ 3  4  3  4 12  3 12  5  4  4]
#  [ 3  3  8 12  3  7  9  9  3  5]
#  [ 6  6  5  9  3  8  4  6  9  8]
#  [ 8  4 11  3  8 12 11  8 10 11]
#  [ 8 11 12 12  4  8 12  4  7 10]
#  [10 10 12 10  9  3  6 12  7  7]]
# The iteration 5
# [[13  8  4  5 13  4  5 12 13  4]
#  [12 10  8  7  4  8 10 12  5 12]
#  [ 8  5  7 10  9  7 13 10 13  5]
#  [13  8  6 10 11 12 12 13  6  4]
#  [10 11 12  5 11  5  8  4 12  9]
#  [ 8 11 12 12  6 10  6 12 12 10]
#  [10  9 10  4  4 10 13  5 12 13]
#  [ 5  6 12 13 13  9  4  6 11  7]
#  [ 4  8  6  4  7  7  5  6  9 13]
#  [ 4  5  4  5 13  4 13  6  5  5]
#  [ 4  4  9 13  4  8 10 10  4  6]
#  [ 7  7  6 10  4  9  5  7 10  9]
#  [ 9  5 12  4  9 13 12  9 11 12]
#  [ 9 12 13 13  5  9 13  5  8 11]
#  [11 11 13 11 10  4  7 13  8  8]]
# The iteration 6
# [[14  9  5  6 14  5  6 13 14  5]
#  [13 11  9  8  5  9 11 13  6 13]
#  [ 9  6  8 11 10  8 14 11 14  6]
#  [14  9  7 11 12 13 13 14  7  5]
#  [11 12 13  6 12  6  9  5 13 10]
#  [ 9 12 13 13  7 11  7 13 13 11]
#  [11 10 11  5  5 11 14  6 13 14]
#  [ 6  7 13 14 14 10  5  7 12  8]
#  [ 5  9  7  5  8  8  6  7 10 14]
#  [ 5  6  5  6 14  5 14  7  6  6]
#  [ 5  5 10 14  5  9 11 11  5  7]
#  [ 8  8  7 11  5 10  6  8 11 10]
#  [10  6 13  5 10 14 13 10 12 13]
#  [10 13 14 14  6 10 14  6  9 12]
#  [12 12 14 12 11  5  8 14  9  9]]
# The iteration 7
# [[15 10  6  7 15  6  7 14 15  6]
#  [14 12 10  9  6 10 12 14  7 14]
#  [10  7  9 12 11  9 15 12 15  7]
#  [15 10  8 12 13 14 14 15  8  6]
#  [12 13 14  7 13  7 10  6 14 11]
#  [10 13 14 14  8 12  8 14 14 12]
#  [12 11 12  6  6 12 15  7 14 15]
#  [ 7  8 14 15 15 11  6  8 13  9]
#  [ 6 10  8  6  9  9  7  8 11 15]
#  [ 6  7  6  7 15  6 15  8  7  7]
#  [ 6  6 11 15  6 10 12 12  6  8]
#  [ 9  9  8 12  6 11  7  9 12 11]
#  [11  7 14  6 11 15 14 11 13 14]
#  [11 14 15 15  7 11 15  7 10 13]
#  [13 13 15 13 12  6  9 15 10 10]]
# The iteration 8
# [[16 11  7  8 16  7  8 15 16  7]
#  [15 13 11 10  7 11 13 15  8 15]
#  [11  8 10 13 12 10 16 13 16  8]
#  [16 11  9 13 14 15 15 16  9  7]
#  [13 14 15  8 14  8 11  7 15 12]
#  [11 14 15 15  9 13  9 15 15 13]
#  [13 12 13  7  7 13 16  8 15 16]
#  [ 8  9 15 16 16 12  7  9 14 10]
#  [ 7 11  9  7 10 10  8  9 12 16]
#  [ 7  8  7  8 16  7 16  9  8  8]
#  [ 7  7 12 16  7 11 13 13  7  9]
#  [10 10  9 13  7 12  8 10 13 12]
#  [12  8 15  7 12 16 15 12 14 15]
#  [12 15 16 16  8 12 16  8 11 14]
#  [14 14 16 14 13  7 10 16 11 11]]
# The iteration 9
# [[17 12  8  9 17  8  9 16 17  8]
#  [16 14 12 11  8 12 14 16  9 16]
#  [12  9 11 14 13 11 17 14 17  9]
#  [17 12 10 14 15 16 16 17 10  8]
#  [14 15 16  9 15  9 12  8 16 13]
#  [12 15 16 16 10 14 10 16 16 14]
#  [14 13 14  8  8 14 17  9 16 17]
#  [ 9 10 16 17 17 13  8 10 15 11]
#  [ 8 12 10  8 11 11  9 10 13 17]
#  [ 8  9  8  9 17  8 17 10  9  9]
#  [ 8  8 13 17  8 12 14 14  8 10]
#  [11 11 10 14  8 13  9 11 14 13]
#  [13  9 16  8 13 17 16 13 15 16]
#  [13 16 17 17  9 13 17  9 12 15]
#  [15 15 17 15 14  8 11 17 12 12]]
# The iteration 10
# [[18 13  9 10 18  9 10 17 18  9]
#  [17 15 13 12  9 13 15 17 10 17]
#  [13 10 12 15 14 12 18 15 18 10]
#  [18 13 11 15 16 17 17 18 11  9]
#  [15 16 17 10 16 10 13  9 17 14]
#  [13 16 17 17 11 15 11 17 17 15]
#  [15 14 15  9  9 15 18 10 17 18]
#  [10 11 17 18 18 14  9 11 16 12]
#  [ 9 13 11  9 12 12 10 11 14 18]
#  [ 9 10  9 10 18  9 18 11 10 10]
#  [ 9  9 14 18  9 13 15 15  9 11]
#  [12 12 11 15  9 14 10 12 15 14]
#  [14 10 17  9 14 18 17 14 16 17]
#  [14 17 18 18 10 14 18 10 13 16]
#  [16 16 18 16 15  9 12 18 13 13]]

# %% [markdown]
# Also there is the method mymean that returns the mean of a random image after a random sensor iterator.

# %%
sensor.mymean()
# Out:
# array([[ 8.5, 13.5,  6.5,  5.5,  5.5],
#        [10.5,  7.5,  8.5,  9.5,  8.5],
#        [ 4.5,  6.5, 12.5,  4.5, 11.5],
#        [10.5,  9.5, 12.5,  6.5,  6.5],
#        [ 4.5,  5.5,  6.5,  7.5,  9.5]])

# %% [markdown]
# Also it can be used in the bash terminal with the pysensor command

# %%
! pysensor
# Out:
# [[10.5 12.5  6.5  9.5  9.5]
#  [ 4.5  8.5  6.5 12.5  7.5]
#  [ 6.5 11.5  4.5  9.5 13.5]
#  [ 9.5  9.5 11.5  8.5 12.5]
#  [ 9.5 13.5  8.5 12.5 10.5]]

# %%
sensor.concurrent()
# Out:
# [[ 7.5  4.5  7.5  5.5  8.5]
#  [ 4.5  6.5  9.5  5.5  5.5]
#  [10.5 12.5  6.5 12.5  9.5]
#  [ 5.5  6.5 13.5 10.5  5.5]
#  [ 4.5  7.5 12.5  9.5  9.5]]
# [[ 8.5  6.5  8.5  8.5 13.5]
#  [ 7.5  9.5 10.5 11.5 13.5]
#  [10.5  9.5  5.5 11.5  6.5]
#  [ 9.5 12.5  6.5  7.5 13.5]
#  [ 4.5 11.5  9.5  7.5 13.5]]
# [[ 4.5  6.5  4.5  7.5  9.5]
#  [ 4.5 12.5  8.5  6.5  7.5]
#  [10.5  9.5  9.5 10.5 12.5]
#  [ 5.5 12.5 11.5 12.5 10.5]
#  [13.5 11.5  5.5  6.5  4.5]]
# [[13.5  4.5 12.5 13.5  6.5]
#  [12.5  6.5  6.5  7.5 11.5]
#  [ 9.5  9.5  4.5  9.5 11.5]
#  [11.5  5.5 12.5  9.5  7.5]
#  [ 9.5  6.5  7.5 12.5  6.5]]
# [[ 8.5  9.5  9.5 10.5 11.5]
#  [11.5 12.5  6.5  7.5 11.5]
#  [11.5 13.5  9.5  5.5 11.5]
#  [13.5  7.5  6.5 10.5  6.5]
#  [12.5  8.5  5.5  4.5 11.5]]
# [[ 6.5 13.5 10.5  5.5 13.5]
#  [ 7.5 10.5  7.5  5.5 12.5]
#  [10.5  8.5  5.5  6.5  8.5]
#  [ 7.5 11.5  9.5 13.5 13.5]
#  [ 5.5  9.5  8.5 12.5  6.5]]
# [[ 9.5  4.5 11.5 13.5 10.5]
#  [12.5 13.5 12.5 11.5  8.5]
#  [ 9.5 13.5  4.5  8.5  6.5]
#  [ 8.5  4.5  4.5  4.5  7.5]
#  [ 4.5  5.5  5.5  5.5 13.5]]
# [[11.5 10.5  6.5 13.5  6.5]
#  [ 7.5 11.5 10.5 13.5  5.5]
#  [ 4.5  4.5 12.5  8.5  8.5]
#  [10.5  6.5  4.5  5.5 12.5]
#  [13.5 12.5  5.5 10.5 12.5]]
# [[ 4.5 12.5 12.5  5.5  7.5]
#  [ 8.5  7.5 12.5  6.5 11.5]
#  [ 7.5  8.5  7.5  4.5  6.5]
#  [ 5.5  4.5  6.5  6.5  5.5]
#  [ 5.5  9.5  8.5  9.5 12.5]]
# [[13.5  4.5  4.5 11.5 10.5]
#  [ 8.5  9.5  8.5  9.5  9.5]
#  [10.5 10.5 10.5  4.5  9.5]
#  [12.5  7.5  5.5 10.5  6.5]
#  [ 9.5  6.5 13.5 10.5  8.5]]
# [[10.5  7.5 13.5  6.5 12.5]
#  [11.5 13.5  4.5  6.5 11.5]
#  [10.5  9.5 12.5 10.5 10.5]
#  [ 6.5  4.5 10.5 10.5  4.5]
#  [ 4.5  6.5  4.5 11.5  5.5]]
# [[12.5  6.5  5.5 10.5  4.5]
#  [11.5 13.5  7.5  4.5  9.5]
#  [ 7.5  7.5  4.5  8.5  8.5]
#  [12.5 10.5  7.5  4.5  4.5]
#  [ 8.5  7.5 12.5  5.5 11.5]]
# [[ 9.5 11.5 10.5  5.5 10.5]
#  [11.5  6.5  4.5  4.5 12.5]
#  [12.5 13.5  8.5 13.5  4.5]
#  [ 7.5  4.5 10.5  7.5  6.5]
#  [13.5 10.5 11.5 10.5 11.5]]
# [[ 6.5  4.5 11.5  6.5 13.5]
#  [ 4.5  9.5  7.5 13.5  4.5]
#  [ 6.5  6.5  8.5 11.5 13.5]
#  [ 7.5  6.5  9.5 10.5  9.5]
#  [ 5.5  7.5 11.5  7.5 13.5]]
# [[ 6.5  8.5  7.5  4.5  6.5]
#  [10.5  8.5  4.5  8.5 13.5]
#  [11.5  7.5  8.5  6.5 13.5]
#  [ 4.5  9.5 13.5  5.5  9.5]
#  [ 4.5  4.5  9.5  7.5  9.5]]
# [[10.5  8.5 11.5  8.5  5.5]
#  [ 4.5 10.5  9.5 12.5 11.5]
#  [ 6.5 11.5 10.5 12.5  6.5]
#  [ 6.5 11.5  6.5 11.5  5.5]
#  [ 6.5  6.5  8.5 12.5 10.5]]
# [[ 4.5  5.5  9.5 11.5  7.5]
#  [13.5 11.5  7.5  8.5 11.5]
#  [ 8.5 12.5  6.5 10.5  5.5]
#  [ 5.5 12.5  6.5  7.5  4.5]
#  [13.5 11.5  6.5 13.5 11.5]]
# [[10.5 13.5  9.5  8.5  4.5]
#  [13.5 12.5 11.5  5.5  8.5]
#  [12.5 11.5  8.5 11.5 13.5]
#  [ 9.5  9.5  6.5  4.5 10.5]
#  [ 4.5 11.5 13.5  9.5  5.5]]
# [[13.5 11.5  5.5  6.5 13.5]
#  [ 7.5  8.5  7.5  4.5  9.5]
#  [ 5.5  5.5  9.5 12.5 13.5]
#  [13.5  4.5  8.5  8.5  5.5]
#  [ 9.5  5.5  6.5  7.5 13.5]]
# [[13.5 10.5  4.5  7.5  5.5]
#  [11.5  7.5  4.5  7.5  8.5]
#  [13.5  8.5  5.5 10.5 11.5]
#  [ 4.5 10.5 13.5  6.5  9.5]
#  [12.5  7.5  4.5 12.5  6.5]]
# [[ 5.5  4.5  9.5  9.5  4.5]
#  [12.5 13.5  8.5  5.5  9.5]
#  [ 5.5 12.5 12.5 12.5 11.5]
#  [10.5 10.5  8.5 10.5  8.5]
#  [ 6.5 13.5  6.5  6.5 10.5]]
# [[11.5  7.5  8.5  6.5 11.5]
#  [ 5.5  8.5  5.5 10.5  8.5]
#  [ 5.5 12.5 11.5 13.5  8.5]
#  [10.5  7.5 13.5 11.5  5.5]
#  [12.5  8.5 13.5  8.5 12.5]]
# [[10.5  8.5 11.5  7.5  4.5]
#  [ 5.5  6.5 11.5 11.5  8.5]
#  [12.5  8.5 11.5  7.5  8.5]
#  [10.5 13.5  4.5 12.5  7.5]
#  [12.5  6.5  9.5  5.5  9.5]]
# [[12.5 10.5  4.5  6.5 10.5]
#  [ 8.5 13.5  5.5  5.5  5.5]
#  [13.5  8.5  9.5  7.5 12.5]
#  [ 6.5  4.5  6.5 10.5  4.5]
#  [ 8.5  7.5 12.5 13.5 13.5]]
# [[ 8.5  4.5  8.5  8.5 11.5]
#  [ 8.5  9.5  6.5 12.5  8.5]
#  [ 6.5  7.5 11.5 12.5 11.5]
#  [ 9.5 10.5  4.5 10.5  7.5]
#  [ 7.5 13.5  7.5 13.5 13.5]]
# [[ 4.5 11.5 13.5 10.5  9.5]
#  [11.5  9.5 13.5  4.5  9.5]
#  [ 9.5  6.5  5.5  9.5  4.5]
#  [11.5 11.5 11.5 10.5 13.5]
#  [ 5.5  7.5  4.5  4.5  9.5]]
# [[12.5  5.5  9.5  4.5  6.5]
#  [ 5.5 11.5  9.5  5.5  7.5]
#  [ 7.5  9.5  4.5  7.5 12.5]
#  [ 4.5  7.5  8.5 13.5  6.5]
#  [ 4.5 12.5  7.5  5.5 13.5]]
# [[ 9.5  6.5 11.5 12.5  9.5]
#  [12.5  4.5 10.5  5.5 11.5]
#  [ 9.5  7.5 12.5  5.5  8.5]
#  [ 7.5  4.5  6.5 13.5 13.5]
#  [ 7.5  9.5  9.5 11.5  6.5]]
# [[10.5  5.5  7.5  4.5  5.5]
#  [13.5 13.5 10.5  5.5  4.5]
#  [ 8.5 13.5 13.5  6.5  5.5]
#  [ 4.5 13.5  4.5 12.5 13.5]
#  [12.5  6.5  4.5  6.5 10.5]]
# [[ 8.5  8.5  5.5  7.5  6.5]
#  [ 9.5  7.5 12.5 10.5 10.5]
#  [10.5 11.5  6.5  8.5 12.5]
#  [ 8.5 12.5  8.5  8.5  5.5]
#  [ 7.5 13.5 11.5 13.5  8.5]]
# [[ 4.5  6.5  8.5 13.5  5.5]
#  [13.5  6.5  4.5 12.5 13.5]
#  [10.5  8.5  7.5  7.5  8.5]
#  [10.5  9.5 12.5 13.5 10.5]
#  [10.5  9.5 12.5  4.5 12.5]]
# [[10.5 11.5  5.5  5.5  6.5]
#  [10.5  6.5 10.5  4.5  5.5]
#  [ 5.5 13.5  9.5 13.5  9.5]
#  [ 8.5  7.5  4.5  7.5  5.5]
#  [ 6.5 11.5  5.5 13.5  4.5]]
# [[ 7.5 13.5  6.5 11.5 12.5]
#  [13.5 12.5  8.5  7.5 12.5]
#  [ 5.5  6.5 11.5  8.5  9.5]
#  [12.5 10.5 12.5  6.5  9.5]
#  [12.5  6.5  8.5  4.5  8.5]]
# [[ 5.5 10.5 11.5  9.5 13.5]
#  [13.5  8.5  8.5 12.5  4.5]
#  [ 6.5 12.5  5.5  6.5  5.5]
#  [11.5  6.5  9.5 13.5 11.5]
#  [ 7.5  7.5  8.5  7.5 10.5]]
# [[ 5.5 10.5  6.5 13.5  6.5]
#  [ 9.5  4.5  5.5 11.5  5.5]
#  [12.5 12.5  5.5  7.5  6.5]
#  [ 7.5 12.5 13.5 10.5 11.5]
#  [11.5 11.5 12.5 10.5  4.5]]
# [[13.5  8.5  6.5  6.5 12.5]
#  [11.5 12.5 11.5  7.5 13.5]
#  [ 5.5  6.5 10.5  7.5  5.5]
#  [12.5  8.5  8.5 13.5  6.5]
#  [10.5  6.5  4.5 10.5  7.5]]
# [[ 4.5 11.5 12.5 11.5 11.5]
#  [ 6.5 10.5  8.5  8.5  9.5]
#  [ 4.5 11.5 12.5  9.5  4.5]
#  [12.5 10.5  8.5 12.5 10.5]
#  [ 6.5  4.5  5.5 13.5  9.5]]
# [[ 8.5 13.5 13.5 13.5  6.5]
#  [ 6.5 12.5 10.5 10.5 11.5]
#  [ 9.5  7.5  5.5 12.5 10.5]
#  [11.5 12.5 11.5 13.5 12.5]
#  [11.5  9.5 13.5  6.5 10.5]]
# [[ 4.5  9.5 12.5 12.5  6.5]
#  [ 7.5 11.5  4.5 12.5 10.5]
#  [12.5 12.5  9.5 12.5  7.5]
#  [ 5.5  6.5  4.5  4.5  8.5]
#  [ 8.5 12.5  9.5 10.5  7.5]]
# [[ 6.5  9.5 11.5 12.5  4.5]
#  [ 5.5  6.5  8.5  8.5 13.5]
#  [ 8.5 10.5 10.5 11.5  8.5]
#  [10.5  7.5  5.5  4.5  5.5]
#  [11.5  8.5  8.5 12.5  9.5]]
# [[12.5 12.5 12.5  8.5  8.5]
#  [ 7.5  9.5  7.5 12.5 12.5]
#  [12.5  5.5  5.5 11.5 10.5]
#  [ 4.5  6.5  5.5  6.5  4.5]
#  [13.5  6.5  5.5  7.5  5.5]]
# [[10.5  4.5  5.5  7.5  6.5]
#  [ 8.5 12.5 10.5  6.5  4.5]
#  [13.5 12.5  9.5 11.5  9.5]
#  [ 6.5  4.5  5.5  7.5 11.5]
#  [ 4.5 11.5  5.5  9.5  4.5]]
# [[ 5.5 13.5  7.5  4.5  9.5]
#  [10.5 13.5 13.5 10.5  5.5]
#  [12.5  5.5  6.5 10.5 10.5]
#  [ 4.5  6.5  8.5  5.5  5.5]
#  [ 4.5 12.5  7.5 12.5  4.5]]
# [[ 6.5  8.5  8.5 11.5  7.5]
#  [12.5 12.5  8.5  8.5 12.5]
#  [10.5  9.5 12.5  9.5  5.5]
#  [ 6.5  6.5  4.5  4.5 10.5]
#  [ 4.5  6.5  8.5  8.5 10.5]]
# [[12.5 13.5 10.5 10.5  4.5]
#  [ 9.5 13.5  4.5  6.5  6.5]
#  [ 4.5  8.5  9.5 12.5  6.5]
#  [10.5  4.5 12.5  5.5  6.5]
#  [ 5.5 10.5 10.5  7.5 12.5]]
# [[ 4.5  6.5  8.5  8.5  8.5]
#  [12.5 10.5 13.5  6.5 10.5]
#  [ 9.5 10.5  8.5  5.5  6.5]
#  [ 4.5  4.5  9.5  9.5 10.5]
#  [ 7.5  4.5 13.5  4.5  5.5]]
# [[ 8.5 11.5 12.5  8.5 12.5]
#  [ 7.5  9.5 10.5 12.5  9.5]
#  [ 6.5  4.5 10.5  9.5 12.5]
#  [12.5  5.5  9.5 10.5  7.5]
#  [ 6.5  4.5  6.5  4.5 13.5]]
# [[ 7.5  4.5 10.5  6.5  5.5]
#  [12.5 10.5 10.5  5.5  9.5]
#  [ 4.5  9.5  9.5  8.5 10.5]
#  [ 4.5 13.5 13.5  8.5  9.5]
#  [ 6.5  7.5 11.5  4.5  9.5]]
# [[ 5.5  5.5 13.5  9.5 10.5]
#  [ 9.5  6.5  8.5  5.5  8.5]
#  [ 6.5  5.5 11.5  4.5  9.5]
#  [13.5  7.5  6.5  5.5  4.5]
#  [12.5  5.5 13.5  7.5  5.5]]
# [[ 4.5  6.5  9.5  6.5  7.5]
#  [10.5  4.5  5.5  9.5  6.5]
#  [ 5.5  9.5  6.5  6.5  6.5]
#  [ 6.5  9.5  8.5  7.5  4.5]
#  [ 6.5  6.5 10.5  8.5 10.5]]
# [[ 8.5  4.5 11.5  4.5 13.5]
#  [10.5 12.5 11.5 13.5  7.5]
#  [ 4.5 11.5  9.5 10.5 12.5]
#  [12.5  4.5  9.5  9.5  9.5]
#  [11.5  5.5 11.5  4.5 11.5]]
# [[ 6.5 13.5  4.5 13.5  8.5]
#  [12.5 12.5  4.5  4.5 13.5]
#  [12.5 12.5  7.5  9.5  6.5]
#  [12.5  6.5 10.5 13.5  9.5]
#  [12.5  9.5 10.5  4.5  5.5]]
# [[ 8.5 11.5 11.5 11.5 11.5]
#  [ 7.5 13.5 12.5  4.5 12.5]
#  [10.5  8.5 10.5 11.5  9.5]
#  [13.5  5.5 11.5 13.5  7.5]
#  [ 9.5  7.5  6.5 13.5  6.5]]
# [[10.5 10.5  5.5 13.5  9.5]
#  [ 7.5  5.5 12.5  5.5 10.5]
#  [ 6.5  8.5  5.5 13.5  7.5]
#  [ 4.5  8.5  5.5  8.5  9.5]
#  [ 5.5  5.5  6.5  7.5  7.5]]
# [[ 6.5  4.5  6.5 13.5  9.5]
#  [10.5  8.5 11.5  6.5 12.5]
#  [ 9.5  8.5  8.5  9.5 13.5]
#  [ 9.5  8.5  8.5  9.5  9.5]
#  [ 5.5  5.5 10.5 12.5 10.5]]
# [[10.5 11.5 12.5 11.5 10.5]
#  [11.5 11.5  4.5  7.5  4.5]
#  [12.5  4.5 10.5 11.5  7.5]
#  [11.5  5.5  4.5 10.5  5.5]
#  [11.5 10.5 12.5  4.5 12.5]]
# [[ 9.5 11.5  8.5  7.5 11.5]
#  [ 8.5 13.5  7.5  6.5 11.5]
#  [12.5  6.5  9.5  5.5  8.5]
#  [ 8.5 10.5 13.5  8.5  6.5]
#  [ 9.5  6.5  4.5  9.5  4.5]]
# [[ 7.5  7.5 11.5 12.5 11.5]
#  [ 6.5  8.5  9.5  6.5  6.5]
#  [ 9.5 13.5  7.5  6.5  9.5]
#  [ 6.5  9.5  5.5  5.5 13.5]
#  [ 5.5  4.5  8.5  8.5  8.5]]
# [[ 7.5  9.5 12.5 10.5 10.5]
#  [ 6.5 12.5  4.5  6.5 12.5]
#  [ 4.5  5.5  4.5 11.5  4.5]
#  [ 6.5 11.5  4.5 11.5  4.5]
#  [ 8.5  4.5 11.5  7.5  8.5]]
# [[ 6.5  8.5  7.5  7.5  8.5]
#  [13.5  6.5  6.5 12.5  5.5]
#  [ 5.5  6.5  5.5  4.5  4.5]
#  [ 5.5 10.5 13.5 13.5  6.5]
#  [ 5.5 10.5  8.5  7.5  4.5]]
# [[ 6.5  4.5  6.5  6.5 10.5]
#  [10.5 11.5 11.5 10.5  8.5]
#  [11.5  6.5 12.5 12.5 12.5]
#  [ 6.5  5.5  7.5  6.5 11.5]
#  [10.5 11.5 11.5  9.5  7.5]]
# [[ 9.5 12.5  7.5 10.5  8.5]
#  [13.5  7.5  4.5 10.5  4.5]
#  [ 9.5 12.5  6.5 12.5  6.5]
#  [ 7.5  5.5  9.5  7.5 11.5]
#  [11.5 13.5 11.5  5.5 11.5]]
# [[ 4.5 12.5  7.5  7.5  9.5]
#  [ 4.5 13.5  4.5  7.5  4.5]
#  [11.5  5.5  5.5 10.5  7.5]
#  [10.5 11.5  9.5 12.5  9.5]
#  [ 8.5  4.5  4.5  7.5 12.5]]
# [[ 6.5  5.5 12.5  7.5  4.5]
#  [ 8.5 11.5  4.5 11.5  9.5]
#  [13.5  6.5 10.5  5.5  5.5]
#  [ 4.5 10.5  8.5 13.5 11.5]
#  [ 8.5 12.5  8.5 12.5  7.5]]
# [[ 8.5 12.5 11.5 10.5  5.5]
#  [ 7.5 12.5  6.5  8.5 11.5]
#  [ 9.5 12.5 10.5 10.5  5.5]
#  [ 9.5 12.5 10.5 13.5  6.5]
#  [ 7.5 12.5  5.5 12.5 10.5]]
# [[ 8.5 12.5 11.5  7.5 12.5]
#  [12.5 11.5 10.5 11.5 10.5]
#  [10.5  5.5 11.5  6.5 11.5]
#  [12.5 11.5 12.5  9.5 13.5]
#  [ 9.5  8.5 10.5  5.5  9.5]]
# [[ 9.5  5.5  9.5  7.5 12.5]
#  [ 6.5  6.5  7.5  7.5 11.5]
#  [11.5  4.5  9.5  4.5  7.5]
#  [13.5  9.5  7.5  7.5  6.5]
#  [12.5  4.5  5.5 13.5  5.5]]
# [[ 4.5 13.5  7.5  4.5 11.5]
#  [ 8.5  4.5 11.5  8.5 13.5]
#  [ 5.5 10.5  6.5 12.5  8.5]
#  [ 6.5 13.5  6.5 11.5  9.5]
#  [11.5  6.5  5.5  8.5  5.5]]
# [[13.5  9.5  7.5 11.5  6.5]
#  [12.5  5.5  6.5  9.5 10.5]
#  [10.5  5.5  5.5 12.5 10.5]
#  [ 8.5  6.5 13.5  7.5 11.5]
#  [13.5  5.5 12.5  8.5  8.5]]
# [[ 9.5  5.5 12.5  4.5  6.5]
#  [ 6.5 12.5  6.5  8.5 13.5]
#  [10.5 10.5  9.5  6.5  4.5]
#  [ 4.5  8.5  9.5  6.5  8.5]
#  [ 7.5  4.5 10.5  8.5  8.5]]
# [[10.5  4.5  7.5  4.5  4.5]
#  [ 7.5 12.5  7.5 13.5 12.5]
#  [ 7.5 10.5 10.5  7.5  4.5]
#  [11.5  5.5 10.5 13.5 10.5]
#  [10.5 10.5 11.5 10.5  8.5]]
# [[13.5 11.5  5.5  9.5  7.5]
#  [13.5 10.5 13.5  7.5 13.5]
#  [ 9.5  9.5  7.5  4.5  5.5]
#  [ 7.5 11.5  7.5  4.5 12.5]
#  [ 8.5  4.5  4.5 12.5  8.5]]
# [[12.5  8.5  5.5  4.5  5.5]
#  [ 5.5  9.5 13.5  4.5  8.5]
#  [ 6.5 11.5  6.5  7.5  8.5]
#  [ 5.5 10.5  8.5  4.5 10.5]
#  [ 8.5  6.5 11.5  8.5  6.5]]
# [[ 4.5 12.5 10.5  9.5  6.5]
#  [10.5 11.5  7.5  4.5  8.5]
#  [ 8.5 13.5  5.5  4.5  4.5]
#  [ 6.5  4.5  9.5 12.5  8.5]
#  [ 7.5 13.5 11.5  7.5 11.5]]
# [[13.5  4.5  4.5  4.5 13.5]
#  [ 5.5 11.5  6.5  6.5 12.5]
#  [ 5.5  4.5  7.5  4.5  6.5]
#  [10.5  4.5  6.5  9.5 12.5]
#  [ 5.5  4.5 12.5  4.5 11.5]]
# [[11.5  4.5 11.5 11.5 10.5]
#  [ 4.5  5.5 12.5  4.5 13.5]
#  [ 7.5  6.5  5.5  7.5 13.5]
#  [ 5.5  5.5 11.5 10.5  7.5]
#  [ 6.5 10.5  4.5  9.5  6.5]]
# [[ 6.5  4.5  5.5 10.5  9.5]
#  [13.5  7.5  7.5  8.5  5.5]
#  [ 7.5  7.5 12.5 12.5 12.5]
#  [10.5  7.5 13.5 11.5  8.5]
#  [ 5.5  9.5 12.5  7.5  8.5]]
# [[ 9.5  5.5  9.5 11.5 13.5]
#  [ 6.5  7.5  7.5 12.5  5.5]
#  [13.5 13.5 10.5  4.5 13.5]
#  [13.5 11.5  6.5  6.5 13.5]
#  [10.5  4.5  7.5 11.5 10.5]]
# [[13.5 13.5  5.5  8.5  4.5]
#  [ 9.5  9.5 13.5  9.5 10.5]
#  [12.5 10.5  9.5  5.5 11.5]
#  [ 5.5 10.5  4.5 12.5 13.5]
#  [11.5  6.5  4.5  5.5  7.5]]
# [[13.5 10.5  9.5  8.5 13.5]
#  [13.5  5.5  4.5 13.5 10.5]
#  [12.5  4.5 11.5  8.5  9.5]
#  [ 8.5 13.5  6.5  9.5 12.5]
#  [10.5 13.5  6.5 10.5  8.5]]
# [[ 4.5  6.5 10.5 11.5  5.5]
#  [12.5  6.5  5.5  7.5 12.5]
#  [13.5 10.5  6.5 13.5  8.5]
#  [ 4.5 12.5 12.5  8.5  7.5]
#  [ 5.5 11.5  9.5  9.5  4.5]]
# [[11.5  8.5  7.5  7.5 11.5]
#  [ 8.5 11.5  6.5  8.5  5.5]
#  [12.5  6.5  4.5  8.5 11.5]
#  [ 8.5  5.5  6.5 12.5  4.5]
#  [ 5.5 13.5  6.5 11.5  4.5]]
# [[12.5  7.5  7.5  5.5 11.5]
#  [ 5.5  6.5 13.5 13.5 13.5]
#  [13.5  6.5  4.5 13.5  8.5]
#  [13.5 11.5 12.5 13.5  7.5]
#  [12.5  7.5 12.5  4.5  9.5]]
# [[13.5 11.5  5.5  5.5 11.5]
#  [ 7.5 13.5  7.5 10.5  9.5]
#  [ 9.5  8.5 11.5  4.5  4.5]
#  [ 8.5 12.5  9.5 11.5  9.5]
#  [11.5  7.5 10.5 12.5  4.5]]
# [[ 8.5 10.5  4.5  4.5  9.5]
#  [10.5  6.5  7.5  8.5 13.5]
#  [13.5  9.5 13.5  7.5  8.5]
#  [ 4.5  7.5  6.5  9.5 13.5]
#  [ 4.5  4.5 10.5 12.5  9.5]]
# [[ 5.5  4.5 11.5 11.5  8.5]
#  [ 8.5  9.5 12.5  8.5  7.5]
#  [ 6.5  9.5  4.5  6.5 13.5]
#  [ 7.5  4.5 10.5  8.5  8.5]
#  [ 9.5 10.5 13.5 11.5  8.5]]
# [[ 7.5 11.5  7.5  4.5  6.5]
#  [12.5 13.5  4.5  8.5 12.5]
#  [10.5  8.5  7.5  5.5 12.5]
#  [ 6.5 12.5  7.5 10.5  7.5]
#  [ 6.5  8.5 13.5  8.5  9.5]]
# [[ 7.5 12.5  7.5 10.5 11.5]
#  [ 4.5 11.5  4.5  4.5  5.5]
#  [10.5  6.5 13.5 13.5  5.5]
#  [ 9.5 11.5  7.5  5.5 13.5]
#  [ 6.5  4.5  6.5  4.5  4.5]]
# [[12.5  5.5 10.5 12.5  4.5]
#  [13.5 10.5  7.5  6.5 11.5]
#  [11.5 13.5  4.5  5.5 10.5]
#  [ 7.5  4.5 12.5 13.5  6.5]
#  [13.5  9.5  9.5  7.5  4.5]]
# [[12.5 13.5 13.5 13.5 11.5]
#  [ 9.5 11.5  7.5 12.5 11.5]
#  [13.5  6.5 13.5 11.5  9.5]
#  [ 7.5  7.5  6.5  4.5 11.5]
#  [ 5.5 10.5  9.5  8.5  6.5]]
# [[ 7.5 12.5 11.5  8.5  5.5]
#  [ 7.5  8.5  7.5 11.5 10.5]
#  [11.5 11.5 11.5 10.5  5.5]
#  [ 7.5  9.5  5.5  5.5 11.5]
#  [10.5 11.5 12.5  6.5  5.5]]
# [[11.5  5.5  6.5  9.5 13.5]
#  [12.5  9.5  7.5  6.5  6.5]
#  [ 8.5 10.5 12.5  4.5  7.5]
#  [13.5 13.5  6.5 11.5  6.5]
#  [ 7.5  8.5  4.5  7.5  4.5]]
# [[11.5 12.5  9.5 12.5  6.5]
#  [ 8.5  7.5  8.5  7.5  9.5]
#  [ 9.5 11.5  7.5 13.5 11.5]
#  [ 8.5 10.5 11.5  6.5 11.5]
#  [12.5 10.5  7.5 12.5  7.5]]
# [[12.5  5.5  8.5 12.5  9.5]
#  [ 5.5  6.5 11.5  4.5 12.5]
#  [ 5.5 11.5 13.5  6.5 13.5]
#  [ 4.5  8.5 11.5 13.5  7.5]
#  [ 6.5 10.5 11.5 13.5  9.5]]
# [[10.5 12.5 13.5  5.5 12.5]
#  [11.5 13.5 13.5  6.5  5.5]
#  [11.5 11.5 10.5  8.5 10.5]
#  [ 6.5  6.5  5.5 12.5 13.5]
#  [ 6.5  7.5  9.5 12.5  6.5]]
# [[ 4.5  6.5  8.5  6.5  5.5]
#  [10.5  6.5  9.5 12.5  9.5]
#  [11.5 11.5  7.5 13.5  7.5]
#  [13.5  4.5  9.5  4.5  9.5]
#  [10.5  6.5 13.5  9.5  7.5]]
# [[10.5  6.5  6.5  9.5 11.5]
#  [12.5  8.5 11.5 11.5  8.5]
#  [10.5 13.5  9.5  9.5 11.5]
#  [ 5.5 10.5  4.5  4.5 12.5]
#  [ 9.5  4.5 10.5  4.5  9.5]]
# [[ 4.5  6.5  4.5  8.5  8.5]
#  [13.5  4.5  9.5 11.5 13.5]
#  [ 9.5 11.5  9.5 11.5 13.5]
#  [ 9.5  7.5 10.5  5.5 10.5]
#  [ 8.5 12.5 12.5 11.5 12.5]]
# [[ 7.5 10.5 12.5 10.5  5.5]
#  [ 8.5 10.5  9.5  8.5  7.5]
#  [ 5.5  7.5 11.5  4.5  5.5]
#  [ 5.5 13.5  7.5  9.5 13.5]
#  [12.5  8.5 10.5 13.5  5.5]]
# [[10.5 13.5 13.5 13.5  5.5]
#  [ 9.5  9.5  6.5 13.5 11.5]
#  [ 9.5  6.5  8.5  9.5  6.5]
#  [11.5  4.5  8.5 13.5  8.5]
#  [11.5  4.5 10.5  8.5  9.5]]
